# %% [markdown]
# <a href="https://colab.research.google.com/github/GeethmaMunasinghe/Digital_Image_Processing/blob/main/Skill_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('image_01.jpg')

# Display the original image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=539x360>

# %%
height, width, channels = image.shape
num_pixels = image.size
data_type = image.dtype

print(f"Height: {height} pixels")
print(f"Width: {width} pixels")
print(f"Number of Channels: {channels}")
print(f"Total Number of Pixels: {num_pixels}")
print(f"Data Type: {data_type}")
# Out:
# Height: 360 pixels
# Width: 539 pixels
# Number of Channels: 3
# Total Number of Pixels: 582120
# Data Type: uint8

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=539x360>

# %%
resized_image = cv2.resize(image, (270, 180))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=270x180>

# %%
rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=360x539>

# %%
blurred_image = cv2.GaussianBlur(image, (17, 17), 0)
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=RGB size=539x360>

# %%
image[0:10, 0:10] = [193, 224, 44]
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=539x360>
