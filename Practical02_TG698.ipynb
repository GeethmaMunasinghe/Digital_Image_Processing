# %% [markdown]
# <a href="https://colab.research.google.com/github/GeethmaMunasinghe/Digital_Image_Processing/blob/main/Practical02_TG698.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

from google.colab.patches import cv2_imshow

# %% [markdown]
# Question 01

# %%
image=cv2.imread('image_02.png')

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=642x357>

# %% [markdown]
# Question 02

# %%
#Write the image back to the Google Colab environment as "Original Image.jpg"

cv2.imwrite('Original Image.jpg',image)
# Out:
# True

# %% [markdown]
# Question *03*
#
# Load and Assign the "Original Image.jpg" image to "Org_image" variable

# %%
Org_image=cv2.imread('Original Image.jpg')

# %% [markdown]
# Question 04
#
# Display the original image using "Org_image" variable

# %%
cv2_imshow(Org_image)
# Out:
# <PIL.Image.Image image mode=RGB size=642x357>

# %% [markdown]
# Question 05
#
# Modify the pixel values given image at the range

# %%
for x in range(10):
  for y in range(10):
    image[x,y]=[255,100,255]

cv2.imwrite("Modified Image.jpg",image)
cv2.imread("Modified Image.jpg",image)
# Out:
# array([[[255,  97, 255],
#         [255,  99, 255],
#         [251, 101, 254],
#         ...,
#         [ 27,  29,  29],
#         [ 28,  30,  30],
#         [ 28,  30,  30]],
#
#        [[255,  99, 255],
#         [254, 100, 255],
#         [251, 102, 252],
#         ...,
#         [ 31,  33,  33],
#         [ 28,  30,  30],
#         [ 28,  30,  30]],
#
#        [[253, 102, 252],
#         [253, 102, 252],
#         [251, 103, 251],
#         ...,
#         [ 28,  30,  30],
#         [ 28,  30,  30],
#         [ 28,  30,  30]],
#
#        ...,
#
#        [[  2,  24,  12],
#         [  2,  24,  12],
#         [  4,  24,  12],
#         ...,
#         [ 28,  30,  30],
#         [ 28,  30,  30],
#         [ 28,  30,  30]],
#
#        [[  2,  24,  12],
#         [  2,  24,  12],
#         [  4,  24,  12],
#         ...,
#         [ 28,  30,  30],
#         [ 28,  30,  30],
#         [ 28,  30,  30]],
#
#        [[  1,  23,  11],
#         [  2,  24,  12],
#         [  3,  23,  11],
#         ...,
#         [ 28,  30,  30],
#         [ 28,  30,  30],
#         [ 28,  30,  30]]], dtype=uint8)

# %%
image2=cv2.imread("Modified Image.jpg")
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=642x357>

# %% [markdown]
# Question 06

# %%
height=Org_image.shape[0]
print("Height: ",height)

weight=Org_image.shape[1]
print("Weight: ",weight)

channel=Org_image.shape[2]
print("Channel: ",channel)

total_pixel=Org_image.size
print("Total_pixel: ",total_pixel)

data_type=Org_image.dtype
print("Data_Type: ",data_type)
# Out:
# Height:  357
# Weight:  642
# Channel:  3
# Total_pixel:  687582
# Data_Type:  uint8

# %% [markdown]
# Question 07

# %%
roi=image[0:100,0:100]
cv2.imwrite("ROI.jpg",roi)
# Out:
# True

# %%
image=cv2.imread("ROI.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# Question 08
#
# Load the "opencv_logo.png" and split that image into its color channels and display seperately.

# %%
image2=cv2.imread("opencv_logo.png")
cv2_imshow(image2)

B,G,R =cv2.split(image2)

cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
